# %% [markdown]
# <a href="https://colab.research.google.com/github/makerseok/study-dl/blob/main/day02/day02_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 타이타닉 생존자 예측

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
pd.set_option('display.max_columns', 15)
pd.set_option('display.max_row', 500)

# %% [markdown]
# ### 데이터 로드

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
raw_data = sns.load_dataset('titanic')
raw_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %% [markdown]
# ## 데이터 전처리

# %%
# 전처리가 끝난 값을 저장할 변수
clean_data = raw_data

# %% [markdown]
# ### 중복 값 제거

# %%
# age와 who가 같고, survived와 alive가 같으므로 각각 하나씩 남김
clean_data.drop(['who', 'alive'], axis=1, inplace=True)

# %%
clean_data['embark_town'].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
clean_data['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
# embark_town과 embarked 또한 같으므로 embark_town만 남김
clean_data.drop(['embarked'], axis=1, inplace=True)

# %% [markdown]
# ### 결측값 처리

# %%
# 결측값 수 확인
clean_data.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# class            0
# adult_male       0
# deck           688
# embark_town      2
# alone            0
# dtype: int64

# %%
# deck은 과반수 이상이 결측값이므로 drop
clean_data.drop('deck', axis=1, inplace=True)

# %%
# embark_town은 2개의 결측값을 가지므로 결측값을 가진 행을 drop
clean_data.dropna(subset=['embark_town'], inplace=True)

# %%
# fare가 0인 승객도 drop
clean_data['fare'] = clean_data['fare'].replace(0, np.nan)
clean_data.dropna(subset=['fare'], inplace=True)

# %%
# age에 결측값을 포함할 경우도 drop
clean_data.dropna(subset=['age'], inplace=True)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 705 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     705 non-null    int64
#  1   pclass       705 non-null    int64
#  2   sex          705 non-null    object
#  3   age          705 non-null    float64
#  4   sibsp        705 non-null    int64
#  5   parch        705 non-null    int64
#  6   fare         705 non-null    float64
#  7   class        705 non-null    category
#  8   adult_male   705 non-null    bool
#  9   embark_town  705 non-null    object
#  10  alone        705 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(2)
# memory usage: 51.7+ KB

# %% [markdown]
# ### 데이터 라벨링

# %%
from sklearn.preprocessing import LabelEncoder

# %%
clean_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class  \
# 0           0       3    male  22.0      1      0   7.2500   Third
# 1           1       1  female  38.0      1      0  71.2833   First
# 2           1       3  female  26.0      0      0   7.9250   Third
# 3           1       1  female  35.0      1      0  53.1000   First
# 4           0       3    male  35.0      0      0   8.0500   Third
# ..        ...     ...     ...   ...    ...    ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250   Third
# 886         0       2    male  27.0      0      0  13.0000  Second
# 887         1       1  female  19.0      0      0  30.0000   First
# 889         1       1    male  26.0      0      0  30.0000   First
# 890         0       3    male  32.0      0      0   7.7500   Third
#
#      adult_male  embark_town  alone
# 0          True  Southampton  False
# 1         False    Cherbourg  False
# 2         False  Southampton   True
# 3         False  Southampton  False
# 4          True  Southampton   True
# ..          ...          ...    ...
# 885       False   Queenstown  False
# 886        True  Southampton   True
# 887       False  Southampton   True
# 889        True    Cherbourg   True
# 890        True   Queenstown   True
#
# [705 rows x 11 columns]

# %%
# 숫자 형식이 아닌 데이터 모두 라벨링
le = LabelEncoder()
clean_data['sex'] = le.fit_transform(clean_data['sex'])
clean_data['class'] = le.fit_transform(clean_data['class'])
clean_data['embark_town'] = le.fit_transform(clean_data['embark_town'])
clean_data['adult_male'] = le.fit_transform(clean_data['adult_male'])
clean_data['alone'] = le.fit_transform(clean_data['alone'])

# %%
clean_data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare  class  adult_male  \
# 0           0       3    1  22.0      1      0   7.2500      2           1
# 1           1       1    0  38.0      1      0  71.2833      0           0
# 2           1       3    0  26.0      0      0   7.9250      2           0
# 3           1       1    0  35.0      1      0  53.1000      0           0
# 4           0       3    1  35.0      0      0   8.0500      2           1
# ..        ...     ...  ...   ...    ...    ...      ...    ...         ...
# 885         0       3    0  39.0      0      5  29.1250      2           0
# 886         0       2    1  27.0      0      0  13.0000      1           1
# 887         1       1    0  19.0      0      0  30.0000      0           0
# 889         1       1    1  26.0      0      0  30.0000      0           1
# 890         0       3    1  32.0      0      0   7.7500      2           1
#
#      embark_town  alone
# 0              2      0
# 1              0      0
# 2              2      1
# 3              2      0
# 4              2      1
# ..           ...    ...
# 885            1      0
# 886            2      1
# 887            2      1
# 889            0      1
# 890            1      1
#
# [705 rows x 11 columns]

# %% [markdown]
# ## feature, target 분리

# %%
feature_col = clean_data.columns[1:]
target_col = clean_data.columns[0]

# %%
feature = clean_data[feature_col]
target = clean_data[target_col]

# %% [markdown]
# ## feature scaling

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = StandardScaler()
scaled_feature = scaler.fit_transform(feature)
scaled_feature = pd.DataFrame(scaled_feature, columns=feature_col)
scaled_feature
# Out:
#        pclass       sex       age     sibsp     parch      fare     class  \
# 0    0.909317  0.762048 -0.522747  0.515257 -0.509948 -0.521398  0.909317
# 1   -1.487201 -1.312253  0.579590  0.515257 -0.509948  0.685625 -1.487201
# 2    0.909317 -1.312253 -0.247163 -0.556295 -0.509948 -0.508674  0.909317
# 3   -1.487201 -1.312253  0.372902  0.515257 -0.509948  0.342871 -1.487201
# 4    0.909317  0.762048  0.372902 -0.556295 -0.509948 -0.506318  0.909317
# ..        ...       ...       ...       ...       ...       ...       ...
# 700  0.909317 -1.312253  0.648486 -0.556295  5.326305 -0.109056  0.909317
# 701 -0.288942  0.762048 -0.178267 -0.556295 -0.509948 -0.413011 -0.288942
# 702 -1.487201 -1.312253 -0.729435 -0.556295 -0.509948 -0.092562 -1.487201
# 703 -1.487201  0.762048 -0.247163 -0.556295 -0.509948 -0.092562 -1.487201
# 704  0.909317  0.762048  0.166213 -0.556295 -0.509948 -0.511973  0.909317
#
#      adult_male  embark_town     alone
# 0      0.858169     0.522863 -1.128802
# 1     -1.165272    -2.036985 -1.128802
# 2     -1.165272     0.522863  0.885895
# 3     -1.165272     0.522863 -1.128802
# 4      0.858169     0.522863  0.885895
# ..          ...          ...       ...
# 700   -1.165272    -0.757061 -1.128802
# 701    0.858169     0.522863  0.885895
# 702   -1.165272     0.522863  0.885895
# 703    0.858169    -2.036985  0.885895
# 704    0.858169    -0.757061  0.885895
#
# [705 rows x 10 columns]

# %% [markdown]
# ## 데이터를 train과 test로 분리

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    scaled_feature, target, test_size=.3, stratify=target
)
print('X_train shape:', X_train.shape)
print('y_train shape:', y_train.shape)
print('X_test shape:', X_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# X_train shape: (493, 10)
# y_train shape: (493,)
# X_test shape: (212, 10)
# y_test shape: (212,)

# %% [markdown]
# ## 모델 생성

# %%
model = Sequential()
model.add(Dense(64, input_dim=10, activation='relu'))
model.add(Dropout(0.5)) # 과적합 방지를 위한 규제(망각)
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.7)) # 과적합 방지를 위한 규제(망각)
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.7)) # 과적합 방지를 위한 규제(망각)
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_181 (Dense)            (None, 64)                704
# _________________________________________________________________
# dropout_133 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_182 (Dense)            (None, 128)               8320
# _________________________________________________________________
# dropout_134 (Dropout)        (None, 128)               0
# _________________________________________________________________
# dense_183 (Dense)            (None, 32)                4128
# _________________________________________________________________
# dropout_135 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_184 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 13,185
# Trainable params: 13,185
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 모델 학습

# %%
model.compile(loss='binary_crossentropy', # 손실함수
              optimizer='adam', # 정규화기
              metrics=['binary_accuracy']) # 평가 기준(학습에 영향 x)
fit_hist = model.fit(X_train, y_train, batch_size=64,
                     epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 32ms/step - loss: 0.7828 - binary_accuracy: 0.4772 - val_loss: 0.6728 - val_binary_accuracy: 0.6768
# Epoch 2/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7468 - binary_accuracy: 0.5228 - val_loss: 0.6617 - val_binary_accuracy: 0.7172
# Epoch 3/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7173 - binary_accuracy: 0.5736 - val_loss: 0.6547 - val_binary_accuracy: 0.7374
# Epoch 4/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6972 - binary_accuracy: 0.6218 - val_loss: 0.6485 - val_binary_accuracy: 0.7273
# Epoch 5/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7186 - binary_accuracy: 0.5660 - val_loss: 0.6441 - val_binary_accuracy: 0.7475
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6655 - binary_accuracy: 0.6041 - val_loss: 0.6411 - val_binary_accuracy: 0.7576
# Epoch 7/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6833 - binary_accuracy: 0.5685 - val_loss: 0.6353 - val_binary_accuracy: 0.7677
# Epoch 8/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6663 - binary_accuracy: 0.6345 - val_loss: 0.6289 - val_binary_accuracy: 0.7677
# Epoch 9/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6422 - binary_accuracy: 0.6548 - val_loss: 0.6228 - val_binary_accuracy: 0.7879
# Epoch 10/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6470 - binary_accuracy: 0.6472 - val_loss: 0.6151 - val_binary_accuracy: 0.7778
# Epoch 11/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6560 - binary_accuracy: 0.6218 - val_loss: 0.6062 - val_binary_accuracy: 0.7879
# Epoch 12/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6715 - binary_accuracy: 0.6396 - val_loss: 0.5969 - val_binary_accuracy: 0.7778
# Epoch 13/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6416 - binary_accuracy: 0.6523 - val_loss: 0.5890 - val_binary_accuracy: 0.7778
# Epoch 14/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6686 - binary_accuracy: 0.6421 - val_loss: 0.5838 - val_binary_accuracy: 0.7677
# Epoch 15/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6279 - binary_accuracy: 0.6726 - val_loss: 0.5788 - val_binary_accuracy: 0.7778
# Epoch 16/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6015 - binary_accuracy: 0.6827 - val_loss: 0.5734 - val_binary_accuracy: 0.7677
# Epoch 17/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6355 - binary_accuracy: 0.6827 - val_loss: 0.5705 - val_binary_accuracy: 0.7677
# Epoch 18/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6134 - binary_accuracy: 0.6929 - val_loss: 0.5656 - val_binary_accuracy: 0.7374
# Epoch 19/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6384 - binary_accuracy: 0.6726 - val_loss: 0.5617 - val_binary_accuracy: 0.7475
# Epoch 20/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6387 - binary_accuracy: 0.6726 - val_loss: 0.5578 - val_binary_accuracy: 0.7273
# Epoch 21/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5968 - binary_accuracy: 0.6929 - val_loss: 0.5516 - val_binary_accuracy: 0.7273
# Epoch 22/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6029 - binary_accuracy: 0.6650 - val_loss: 0.5430 - val_binary_accuracy: 0.7374
# Epoch 23/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5915 - binary_accuracy: 0.7132 - val_loss: 0.5356 - val_binary_accuracy: 0.7273
# Epoch 24/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5694 - binary_accuracy: 0.7284 - val_loss: 0.5290 - val_binary_accuracy: 0.7273
# Epoch 25/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5876 - binary_accuracy: 0.7107 - val_loss: 0.5219 - val_binary_accuracy: 0.7273
# Epoch 26/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5941 - binary_accuracy: 0.7030 - val_loss: 0.5173 - val_binary_accuracy: 0.7374
# Epoch 27/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5626 - binary_accuracy: 0.7538 - val_loss: 0.5128 - val_binary_accuracy: 0.7374
# Epoch 28/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6064 - binary_accuracy: 0.7132 - val_loss: 0.5083 - val_binary_accuracy: 0.7374
# Epoch 29/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5691 - binary_accuracy: 0.7081 - val_loss: 0.5048 - val_binary_accuracy: 0.7475
# Epoch 30/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5406 - binary_accuracy: 0.7690 - val_loss: 0.5016 - val_binary_accuracy: 0.7475
# Epoch 31/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5810 - binary_accuracy: 0.7411 - val_loss: 0.4986 - val_binary_accuracy: 0.7576
# Epoch 32/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6080 - binary_accuracy: 0.7081 - val_loss: 0.4970 - val_binary_accuracy: 0.7576
# Epoch 33/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5569 - binary_accuracy: 0.7157 - val_loss: 0.4970 - val_binary_accuracy: 0.7576
# Epoch 34/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5433 - binary_accuracy: 0.7386 - val_loss: 0.4955 - val_binary_accuracy: 0.7475
# Epoch 35/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5555 - binary_accuracy: 0.7487 - val_loss: 0.4919 - val_binary_accuracy: 0.7475
# Epoch 36/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5531 - binary_accuracy: 0.7284 - val_loss: 0.4890 - val_binary_accuracy: 0.7475
# Epoch 37/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5861 - binary_accuracy: 0.7056 - val_loss: 0.4905 - val_binary_accuracy: 0.7576
# Epoch 38/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5208 - binary_accuracy: 0.7868 - val_loss: 0.4883 - val_binary_accuracy: 0.7576
# Epoch 39/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5263 - binary_accuracy: 0.7843 - val_loss: 0.4855 - val_binary_accuracy: 0.7677
# Epoch 40/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5913 - binary_accuracy: 0.7487 - val_loss: 0.4843 - val_binary_accuracy: 0.7677
# Epoch 41/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5541 - binary_accuracy: 0.7589 - val_loss: 0.4841 - val_binary_accuracy: 0.7778
# Epoch 42/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5255 - binary_accuracy: 0.7563 - val_loss: 0.4814 - val_binary_accuracy: 0.7778
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.5169 - binary_accuracy: 0.7817 - val_loss: 0.4792 - val_binary_accuracy: 0.7778
# Epoch 44/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5396 - binary_accuracy: 0.7437 - val_loss: 0.4766 - val_binary_accuracy: 0.7778
# Epoch 45/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5495 - binary_accuracy: 0.7589 - val_loss: 0.4744 - val_binary_accuracy: 0.7879
# Epoch 46/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5178 - binary_accuracy: 0.7741 - val_loss: 0.4730 - val_binary_accuracy: 0.7879
# Epoch 47/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5466 - binary_accuracy: 0.7665 - val_loss: 0.4732 - val_binary_accuracy: 0.7778
# Epoch 48/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5159 - binary_accuracy: 0.7563 - val_loss: 0.4728 - val_binary_accuracy: 0.7778
# Epoch 49/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5226 - binary_accuracy: 0.7843 - val_loss: 0.4732 - val_binary_accuracy: 0.7778
# Epoch 50/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5225 - binary_accuracy: 0.7741 - val_loss: 0.4725 - val_binary_accuracy: 0.7778
# Epoch 51/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5416 - binary_accuracy: 0.7741 - val_loss: 0.4715 - val_binary_accuracy: 0.7677
# Epoch 52/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5170 - binary_accuracy: 0.7310 - val_loss: 0.4701 - val_binary_accuracy: 0.7879
# Epoch 53/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4920 - binary_accuracy: 0.7817 - val_loss: 0.4701 - val_binary_accuracy: 0.7879
# Epoch 54/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5188 - binary_accuracy: 0.7893 - val_loss: 0.4698 - val_binary_accuracy: 0.7879
# Epoch 55/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5184 - binary_accuracy: 0.7513 - val_loss: 0.4700 - val_binary_accuracy: 0.7879
# Epoch 56/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5367 - binary_accuracy: 0.7640 - val_loss: 0.4701 - val_binary_accuracy: 0.7778
# Epoch 57/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4895 - binary_accuracy: 0.7614 - val_loss: 0.4689 - val_binary_accuracy: 0.7778
# Epoch 58/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5110 - binary_accuracy: 0.7589 - val_loss: 0.4682 - val_binary_accuracy: 0.7778
# Epoch 59/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4926 - binary_accuracy: 0.7919 - val_loss: 0.4689 - val_binary_accuracy: 0.7778
# Epoch 60/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5249 - binary_accuracy: 0.7741 - val_loss: 0.4697 - val_binary_accuracy: 0.7778
# Epoch 61/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5077 - binary_accuracy: 0.7893 - val_loss: 0.4700 - val_binary_accuracy: 0.7677
# Epoch 62/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4890 - binary_accuracy: 0.8020 - val_loss: 0.4698 - val_binary_accuracy: 0.7677
# Epoch 63/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4783 - binary_accuracy: 0.8096 - val_loss: 0.4684 - val_binary_accuracy: 0.7778
# Epoch 64/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5216 - binary_accuracy: 0.7589 - val_loss: 0.4678 - val_binary_accuracy: 0.7879
# Epoch 65/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5021 - binary_accuracy: 0.7640 - val_loss: 0.4694 - val_binary_accuracy: 0.7879
# Epoch 66/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5104 - binary_accuracy: 0.7690 - val_loss: 0.4697 - val_binary_accuracy: 0.7980
# Epoch 67/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5144 - binary_accuracy: 0.7792 - val_loss: 0.4706 - val_binary_accuracy: 0.7879
# Epoch 68/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5014 - binary_accuracy: 0.7690 - val_loss: 0.4701 - val_binary_accuracy: 0.7778
# Epoch 69/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4981 - binary_accuracy: 0.7893 - val_loss: 0.4694 - val_binary_accuracy: 0.7778
# Epoch 70/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4898 - binary_accuracy: 0.7944 - val_loss: 0.4711 - val_binary_accuracy: 0.7778
# Epoch 71/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5304 - binary_accuracy: 0.7741 - val_loss: 0.4719 - val_binary_accuracy: 0.7778
# Epoch 72/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5081 - binary_accuracy: 0.8020 - val_loss: 0.4719 - val_binary_accuracy: 0.7778
# Epoch 73/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4950 - binary_accuracy: 0.7970 - val_loss: 0.4719 - val_binary_accuracy: 0.7778
# Epoch 74/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5200 - binary_accuracy: 0.7766 - val_loss: 0.4705 - val_binary_accuracy: 0.7778
# Epoch 75/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5070 - binary_accuracy: 0.8046 - val_loss: 0.4698 - val_binary_accuracy: 0.7879
# Epoch 76/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4907 - binary_accuracy: 0.7792 - val_loss: 0.4685 - val_binary_accuracy: 0.7980
# Epoch 77/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4782 - binary_accuracy: 0.7665 - val_loss: 0.4668 - val_binary_accuracy: 0.7879
# Epoch 78/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5005 - binary_accuracy: 0.7944 - val_loss: 0.4654 - val_binary_accuracy: 0.7879
# Epoch 79/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4844 - binary_accuracy: 0.7919 - val_loss: 0.4653 - val_binary_accuracy: 0.7879
# Epoch 80/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.5011 - binary_accuracy: 0.7843 - val_loss: 0.4651 - val_binary_accuracy: 0.7879
# Epoch 81/100
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4696 - binary_accuracy: 0.8173 - val_loss: 0.4656 - val_binary_accuracy: 0.7879
# Epoch 82/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4729 - binary_accuracy: 0.7843 - val_loss: 0.4662 - val_binary_accuracy: 0.7879
# Epoch 83/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5072 - binary_accuracy: 0.8122 - val_loss: 0.4656 - val_binary_accuracy: 0.7879
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4764 - binary_accuracy: 0.7792 - val_loss: 0.4657 - val_binary_accuracy: 0.7778
# Epoch 85/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4999 - binary_accuracy: 0.8122 - val_loss: 0.4655 - val_binary_accuracy: 0.7778
# Epoch 86/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4667 - binary_accuracy: 0.8020 - val_loss: 0.4650 - val_binary_accuracy: 0.7778
# Epoch 87/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4558 - binary_accuracy: 0.7893 - val_loss: 0.4655 - val_binary_accuracy: 0.7778
# Epoch 88/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5068 - binary_accuracy: 0.8046 - val_loss: 0.4674 - val_binary_accuracy: 0.7677
# Epoch 89/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4853 - binary_accuracy: 0.8122 - val_loss: 0.4684 - val_binary_accuracy: 0.7677
# Epoch 90/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4805 - binary_accuracy: 0.7919 - val_loss: 0.4697 - val_binary_accuracy: 0.7677
# Epoch 91/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.5094 - binary_accuracy: 0.8096 - val_loss: 0.4697 - val_binary_accuracy: 0.7778
# Epoch 92/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4881 - binary_accuracy: 0.7944 - val_loss: 0.4694 - val_binary_accuracy: 0.7778
# Epoch 93/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4896 - binary_accuracy: 0.7919 - val_loss: 0.4685 - val_binary_accuracy: 0.7778
# Epoch 94/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4648 - binary_accuracy: 0.7919 - val_loss: 0.4681 - val_binary_accuracy: 0.7778
# Epoch 95/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4787 - binary_accuracy: 0.8071 - val_loss: 0.4679 - val_binary_accuracy: 0.7778
# Epoch 96/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4550 - binary_accuracy: 0.8198 - val_loss: 0.4673 - val_binary_accuracy: 0.7778
# Epoch 97/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4905 - binary_accuracy: 0.7970 - val_loss: 0.4673 - val_binary_accuracy: 0.7778
# Epoch 98/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4601 - binary_accuracy: 0.7944 - val_loss: 0.4674 - val_binary_accuracy: 0.7778
# Epoch 99/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.4868 - binary_accuracy: 0.7868 - val_loss: 0.4685 - val_binary_accuracy: 0.7778
# Epoch 100/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4679 - binary_accuracy: 0.8122 - val_loss: 0.4681 - val_binary_accuracy: 0.7677

# %% [markdown]
# ## 결과 확인

# %%
# train, test accuracy 확인
plt.plot(fit_hist.history['binary_accuracy'], label='train')
plt.plot(fit_hist.history['val_binary_accuracy'], label='test')
plt.legend(loc='best')
plt.show()

# %%
# 해당 모델의 loss와 accuracy
score = model.evaluate(X_test, y_test, verbose=1)
print('Keras DNN model loss:', score[0])
print('Keras DNN model accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3846 - binary_accuracy: 0.8679
# Keras DNN model loss: 0.3846142590045929
# Keras DNN model accuracy: 0.8679245114326477

# %%
# confusion matrix, f1 score 확인
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
pred = model.predict(X_test)
pred = (pred > 0.5)
print(confusion_matrix(y_test, pred))
print(f1_score(y_test, pred, average='micro'))
# Out:
# [[108  18]
#  [ 10  76]]
# 0.8679245283018869

# %% [markdown]
# # 테스트용

# %%
error^^
# Out:
#   File "<ipython-input-1495-d7a86043f205>", line 1
#     error^^
#           ^
# SyntaxError: invalid syntax

# %%
age_drop = clean_data.dropna(subset=['age'])

# %%
age_drop.corr()

# %%
age_target_col = age_drop[['age']].columns
age_feature_col = age_drop.columns.difference(['age'])

# %%
age_target_col, age_feature_col.shape

# %%
age_feature = age_drop[age_feature_col]
age_target = age_drop[age_target_col]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_feature = scaler.fit_transform(age_feature)
scaled_feature = pd.DataFrame(scaled_feature, columns=age_feature_col)
scaled_feature

# %%
model = Sequential()
model.add(Dense(512, input_dim=10, activation='relu'))
model.add(Dropout(0.5)) # 과적합 방지를 위한 규제(망각)
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5)) # 과적합 방지를 위한 규제(망각)
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5)) # 과적합 방지를 위한 규제(망각)
model.add(Dense(1))
model.summary()

# %%
age_feature.info()

# %%
model.compile(loss='mse', # 손실함수
              optimizer='adam', # 정규화기
              metrics=['mae', 'mse']) # 평가 기준(학습에 영향 x)
fit_hist = model.fit(age_feature.values, age_target.values, batch_size=50, epochs=100, validation_split=0.3)

# %%
# train, test accuracy 확인
plt.plot(fit_hist.history['mae'], label='train')
plt.plot(fit_hist.history['val_mae'], label='test')
plt.legend(loc='best')
plt.show()

# %%
model.predict(clean_data[clean_data.columns.difference(['age'])])
